# %% [markdown]
# # EDA stands for Exploratory Data Analysis.         :
#
#
# It is the process of exploring, understanding, and analyzing data before building a machine learning model.
#
# # The main goal is to answer questions like:
#
# What does the data look like?
#
# Are there missing values?
#
# Are there outliers?
#
# Which features are important?
# :
# Are patterns or relationships present?

# %% [markdown]
# # **Simple Definition**
#
# # EDA is like “getting to know the dataset” before using it for machine learning.
#
# Just like a doctor examines a patient before treatment, a data analyst examines data before modeling.

# %% [markdown]
# | EDA Task                | Purpose                        |
# | ----------------------- | ------------------------------ |
# | Viewing data            | Understand structure           |
# | Checking missing values | Find incomplete data           |
# | Statistical summary     | Understand averages and spread |
# | Visualizations          | Find patterns and trends       |
# | Outlier detection       | Identify unusual values        |
# | Correlation analysis    | Understand relationships       |

# %% [markdown]
# # **Understanding the Code**
#
# *import pandas as pd*
#
# Imports the Pandas library.
#
# **Pandas is used for:**
#
# Reading datasets
# Cleaning data
# Manipulating tables
# Performing analysis
#
#
# pd is just a short alias.
#
#
#
#
# ---
#
#
#
# *import seaborn as sns*
#
# Seaborn is mainly used for visualization, but it also provides built in datasets like Titanic.
#
# *sns.load_dataset('titanic')*
#
#
# Loads the Titanic dataset into a DataFrame.
#
# A DataFrame is like an Excel sheet inside Python.
#
#
# ---
#
#
# *titanic.head()*
#
# Displays the first 5 rows.
#
# Useful for:
#
# Understanding columns
# Checking data types
# Seeing missing values visually
#
#
# ---
#
# *titanic.info()*
#
# Gives dataset structure:
#
# Number of rows
# Number of columns
# Data types
# Missing values
#
# Example output meaning:
#
# Column	Non Null Count
# age	714
# total rows	891
#
# This means:
#
# 891 − 714 = 177 missing age values

# %% [markdown]
# **Why Data Cleaning Matters**
#
# Real world datasets are rarely perfect.
# The Titanic dataset contains:
#
# Missing values
# Incorrect or extreme values
# Features with very different numerical ranges
#
# Machine learning models learn patterns from data. If the data is poor, the model also becomes poor.

# %%
import seaborn as sns

# Show all available built-in datasets
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
import pandas as pd
import seaborn as sns

# Load dataset
titanic = sns.load_dataset('titanic')

# Print full dataset
print(titanic.to_string())
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class    who  adult_male deck  embark_town alive  alone
# 0           0       3    male  22.00      1      0    7.2500        S   Third    man        True  NaN  Southampton    no  False
# 1           1       1  female  38.00      1      0   71.2833        C   First  woman       False    C    Cherbourg   yes  False
# 2           1       3  female  26.00      0      0    7.9250        S   Third  woman       False  NaN  Southampton   yes   True
# 3           1       1  female  35.00      1      0   53.1000        S   First  woman       False    C  Southampton   yes  False
# 4           0       3    male  35.00      0      0    8.0500        S   Third    man        True  NaN  Southampton    no   True
# 5           0       3    male    NaN      0      0    8.4583        Q   Third    man        True  NaN   Queenstown    no   True
# ...

# %% [markdown]
# to see columns

# %%
import seaborn as sns

# Load Titanic dataset
titanic = sns.load_dataset('titanic')

# Print only column names
print(titanic.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns

# Show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Load dataset
titanic = sns.load_dataset('titanic')

# Display full dataset
display(titanic)
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.00      1      0    7.2500        S   Third
# 1           1       1  female  38.00      1      0   71.2833        C   First
# 2           1       3  female  26.00      0      0    7.9250        S   Third
# 3           1       1  female  35.00      1      0   53.1000        S   First
# 4           0       3    male  35.00      0      0    8.0500        S   Third
# 5           0       3    male    NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.00      0      0   51.8625        S   First
# 7           0       3    male   2.00      3      1   21.0750        S   Third
# 8           1       3  female  27.00      0      2   11.1333        S   Third
# 9           1       2  female  14.00      1      0   30.0708        C  Second
# 10          1       3  female   4.00      1      1   16.7000        S   Third
# ...

# %% [markdown]
# Missing Values
# Check Missing Values bold text

# %%
print(titanic.isnull().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# **Remove Rows with Missing Age**
#
#
# Understanding the Operation
#
# ---
#
#
# *dropna()*
#
# Removes rows containing missing values.
#
# subset=['age']
#
# Only checks the age column.
#
# If age is missing, remove that passenger.
#
# shape
#
# Returns:
#
# (rows, columns)
#
# Example:
#
# (891, 15)
#
# means:
#
# 891 rows
# 15 columns

# %%
titanic_drop = titanic.dropna(subset=['age'])

print("Original Shape:", titanic.shape)
print("After Removing Missing Ages:", titanic_drop.shape)
# Out:
# Original Shape: (891, 15)
# After Removing Missing Ages: (714, 15)

# %% [markdown]
# Understanding Each Operation
# copy()
#
# Creates a duplicate dataset.
#
# Without this, the original dataset changes permanently.
#
# mean()
#
# Calculates average.
#
# ---
#
#
#
# Mean formula:
#
# xˉ=∑x/n
# 	​
#
#
# Where:
#
# ∑x = sum of all values
#
# n = number of values
#
#
#
#
# Example:
#
# Ages = 20, 30, 40
#
# Mean: (20+30+40)/3=30
#
# fillna(mean_age)
#
# Replaces missing values using the calculated average.
#
# Example:
#
# Age Before
# 22
# NaN
# 35
#
# If mean = 29:
#
# Age After
# 22
# 29
# 35
# Why Mean Filling Helps
#
# Advantages:
#
# Keeps all rows
# Simple and fast
#
# Disadvantage:
#
# Can reduce variability
# May introduce bias
#
# **Method 3: Fill Missing Categorical Values Using Mode**
# mode_town = titanic['embark_town'].mode()[0]
#
# titanic['embark_town'] = titanic['embark_town'].fillna(mode_town)
#
# **Understanding Mode**
#
# Mode = most frequent value.
#
# Example:
#
# City
# Chennai
# Bangalore
# Chennai
#
# Mode = Chennai

# %%
titanic_mean = titanic.copy()

mean_age = titanic_mean['age'].mean()

titanic_mean['age'] = titanic_mean['age'].fillna(mean_age)

print("Missing Values After Filling:")
print(titanic_mean['age'].isnull().sum())
# Out:
# Missing Values After Filling:
# 0

# %% [markdown]
#  Fill Missing Categorical Values Using Mode mode_town = titanic
#
# Understanding Mode
#
# Mode = most frequent value.
#
# Example:
#
# City Chennai Bangalore Chennai
#
# Mode = Chennai

# %%
mode_town = titanic['embark_town'].mode()[0]

titanic['embark_town'] = titanic['embark_town'].fillna(mode_town)

# %% [markdown]
# Outlier Detection
# What is an Outlier?
#
# An outlier is an unusually different value.
#
# Example:
#
# Ages
# 20
# 25
# 23
# 200
#
# 200 is suspicious.

# %%
Q1 = titanic['age'].quantile(0.25)
Q3 = titanic['age'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = titanic[(titanic['age'] < lower_bound) |
                   (titanic['age'] > upper_bound)]

print(outliers[['age']].head())
# Out:
#       age
# 33   66.0
# 54   65.0
# 96   71.0
# 116  70.5
# 280  65.0

# %%
import matplotlib.pyplot as plt

plt.boxplot(titanic['age'].dropna())
plt.title("Age Outliers")
plt.show()

# %% [markdown]
# # Data Distribution
# Histogram for Age
# Understanding Countplot
#
# Shows frequency of categories.

# %%
titanic['age'].hist(bins=30)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# # **Gender Wise Survival**

# %% [markdown]
# Understanding Countplot
#
# Shows frequency of categories.
#
# Here:
#
# 0 → Did not survive
#
# 1 → Survived
# Interpretation
#
# Students can observe:
#
# More passengers died than survived

# %%
sns.countplot(x='survived', data=titanic)

plt.title("Survival Count")

plt.show()

# %% [markdown]
# Interpretation
#
# This plot shows:
#
# Female survival rate was much higher
# Many males did not survive
#
# This reveals patterns in the dataset.

# %%
sns.countplot(x='sex', hue='survived', data=titanic)

plt.title("Gender Wise Survival")

plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

titanic['fare_standardized'] = scaler.fit_transform(titanic[['fare']])

# %% [markdown]
# Correlation Heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns

correlation = titanic.corr(numeric_only=True)

plt.figure(figsize=(10,8))

sns.heatmap(correlation,
            annot=True,
            cmap='coolwarm')

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# | Value | Meaning                      |
# | ----- | ---------------------------- |
# | +1    | Strong positive relationship |
# | -1    | Strong negative relationship |
# | 0     | No relationship              |
#
#
# Interpretation Example
#
# We may observe:
#
# Fare and class are related
# Survival has some relation with fare and class
# Sibsp and parch are slightly related

# %% [markdown]
# # Feature Relationship

# %%
sns.scatterplot(x='age',
                y='fare',
                hue='survived',
                data=titanic)

plt.title("Age vs Fare")

plt.show()

# %% [markdown]
# # Understanding Scatter Plot
#
# Shows relationship between two numerical variables.
#
# Students can analyze:
#
# Whether high fare passengers survived more
#
# Distribution of ages
#
# Clusters in data

# %% [markdown]
# # Pairplot
# Why Pairplot is Powerful
#
# It automatically shows:
#
# Scatter plots
# Histograms
# Relationships between multiple variables
#
# Useful for quick dataset exploration.

# %%
sns.pairplot(titanic[['age',
                      'fare',
                      'pclass',
                      'survived']].dropna(),
             hue='survived')

plt.show()

# %% [markdown]
# | Step           | Purpose                |
# | -------------- | ---------------------- |
# | Load dataset   | Read data              |
# | info()         | Understand structure   |
# | describe()     | Statistical summary    |
# | Missing values | Detect incomplete data |
# | Histogram      | Distribution analysis  |
# | Countplot      | Category analysis      |
# | Boxplot        | Outlier detection      |
# | Correlation    | Feature relationships  |
# | Scatterplot    | Variable interaction   |
# | Pairplot       | Multi feature analysis |
# | Cleaning       | Handle missing data    |
# | Scaling        | Normalize features     |

# %% [markdown]
# What Makes This a Good EDA Example
# 1. Dataset Understanding
#
# head()
#
# info()
#
# describe()
#
# These help students understand:
#
# Number of rows and columns
# Data types
# Missing values
# Statistical summary
#
# This is always the first step in EDA.
#
#
# ---
#
#
#
# 2. Missing Value Analysis
# isnull().sum()
#
# fillna()
#
# dropna()
#
#
# Very important in real datasets because almost every real world dataset has incomplete values.
#
# Students learn:
#
# Detecting missing values
# Strategies to handle them
# Effect on model quality
#
#
# ---
#
#
#
# 3. Outlier Detection
#
# Using:
#
# IQR
# Boxplot
#
# is excellent for beginners because it visually explains abnormal data points.
#
# Students understand:
#
# Why unusual values matter
# How outliers affect averages and models
#
#
# ---
#
#
#
# 4. Feature Scaling
#
# Including:
#
# Min Max Scaling
# Standardization
#
# is very useful because many tutorials skip preprocessing explanations.
#
# Students learn why scaling matters for algorithms like:
#
# KNN
# SVM
# Neural Networks
#
#
# ---
#
#
#
#
#
# A stronger EDA workflow would also include:
#
# Additional EDA Steps You Can Add
# 1. Statistical Summary
# print(titanic.describe())
#
# Shows:
#
# Mean
# Median
# Standard deviation
# Min and max
# 2. Data Distribution
#
# Histogram example:
#
# titanic['age'].hist()
#
# Helps understand:
#
# Skewness
# Normal distribution
# Spread
# 3. Correlation Analysis
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# sns.heatmap(titanic.corr(numeric_only=True), annot=True)
# plt.show()
#
# Shows relationships between features.
#
# Example:
#
# Fare and class
# Age and survival
# 4. Survival Analysis
# sns.countplot(x='survived', data=titanic)
#
# Students can explore:
#
# How many survived
# Class wise survival
# Gender wise survival
# 5. Feature Relationships
#
# Example:
#
# sns.scatterplot(x='age', y='fare', hue='survived', data=titanic)
#
# Shows multidimensional relationships visually.

# %% [markdown]
# ---

# %% [markdown]
# ##House Prediction Dataset

# %%
path = "/content/Housing.csv"

df = pd.read_csv(path)

df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df_url = pd.read_csv("https://raw.githubusercontent.com/Baishnab1708/House-Price-Prediction/main/House%20Price%20India.csv")

df_url.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  grade of the house  \
# 0                       5                  10
# ...

# %%
# Install dependencies as needed:
# !pip install kagglehub[pandas-datasets]

# %%
# Install dependencies as needed:
# !pip install kagglehub[polars-datasets]

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
from pathlib import Path

file_path = Path("Housing.csv")

lf = kagglehub.dataset_load(
  KaggleDatasetAdapter.POLARS,
  "harishkumardatalab/housing-price-prediction",
  file_path,
)

print("First 5 records:", lf.collect().head())
# Out:
# Using Colab cache for faster access to the 'housing-price-prediction' dataset.
# First 5 records: shape: (5, 13)
# ┌──────────┬──────┬──────────┬───────────┬───┬────────────────┬─────────┬──────────┬───────────────┐
# │ price    ┆ area ┆ bedrooms ┆ bathrooms ┆ … ┆ airconditionin ┆ parking ┆ prefarea ┆ furnishingsta │
# │ ---      ┆ ---  ┆ ---      ┆ ---       ┆   ┆ g              ┆ ---     ┆ ---      ┆ tus           │
# │ i64      ┆ i64  ┆ i64      ┆ i64       ┆   ┆ ---            ┆ i64     ┆ str      ┆ ---           │
# │          ┆      ┆          ┆           ┆   ┆ str            ┆         ┆          ┆ str           │
# ╞══════════╪══════╪══════════╪═══════════╪═══╪════════════════╪═════════╪══════════╪═══════════════╡
# │ 13300000 ┆ 7420 ┆ 4        ┆ 2         ┆ … ┆ yes            ┆ 2       ┆ yes      ┆ furnished     │
# │ 12250000 ┆ 8960 ┆ 4        ┆ 4         ┆ … ┆ yes            ┆ 3       ┆ no       ┆ furnished     │
# ...

# %%
# display columns

df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
# get rows and columsn

print(df.shape)

print(f"Rows: {df.shape[0]} \nColumns: {df.shape[1]}")
# Out:
# (545, 13)
# Rows: 545
# Columns: 13

# %%
# find null values

df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# ### Basic EDA Graphs for `df`
#
# Let's visualize the distribution of key numerical and categorical features, and explore relationships between them using common plots.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram for 'price' to see its distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], kde=True)
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
# Countplot for 'bedrooms' to see the frequency of different bedroom counts
plt.figure(figsize=(8, 5))
sns.countplot(x='bedrooms', data=df, palette='viridis')
plt.title('Count of Houses by Number of Bedrooms')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /tmp/ipykernel_2959/94718538.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='bedrooms', data=df, palette='viridis')

# %%
# Countplot for 'furnishingstatus' to visualize the distribution of furnishing types
plt.figure(figsize=(10, 6))
sns.countplot(x='furnishingstatus', data=df, palette='magma')
plt.title('Distribution of Furnishing Status')
plt.xlabel('Furnishing Status')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /tmp/ipykernel_2959/4255874482.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='furnishingstatus', data=df, palette='magma')

# %%
# Scatter plot of 'area' vs 'price' to observe their relationship
plt.figure(figsize=(10, 7))
sns.scatterplot(x='area', y='price', data=df, hue='bedrooms', size='bedrooms', sizes=(20, 200), alpha=0.7)
plt.title('House Price vs. Area (Colored by Bedrooms)')
plt.xlabel('Area')
plt.ylabel('Price')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
